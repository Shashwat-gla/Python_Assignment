# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashwat-gla/Python_Assignment/blob/main/crime_in_india_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-000ecb13-b905-4d62-acad-8103b4632c2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-000ecb13-b905-4d62-acad-8103b4632c2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_file = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall("crime_data")

print("Dataset extract ho gaya!")
# Out:
# Dataset extract ho gaya!

# %%
import os

os.listdir("crime_data")
# Out:
# ['20_Victims_of_rape.csv',
#  '28_Trial_of_violent_crimes_by_courts.csv',
#  '40_02_Custodial_death_person_not_remanded.csv',
#  '40_04_Custodial_death_during_hospitalization_or_treatment.csv',
#  '10_Property_stolen_and_recovered.csv',
#  '25_Complaints_against_police.csv',
#  '32_Murder_victim_age_sex.csv',
#  'crime',
#  '29_Period_of_trials_by_courts.csv',
#  '42_Cases_under_crime_against_women.csv',
#  '31_Serious_fraud.csv',
#  '39_Specific_purpose_of_kidnapping_and_abduction.csv',
#  '36_Police_housing.csv',
#  '33_CH_not_murder_victim_age_sex.csv',
#  '43_Arrests_under_crime_against_women.csv',
#  '40_05_Custodial_death_others.csv',
#  '35_Human_rights_violation_by_police.csv',
#  '40_03_Custodial_death_during_production.csv',
#  '40_01_Custodial_death_person_remanded.csv',
#  '30_Auto_theft.csv']

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'crime_data', 'archive.zip', 'archive (1).zip', 'sample_data']

# %%
import os

print(os.listdir("/content/crime_data"))
# Out:
# ['20_Victims_of_rape.csv', '28_Trial_of_violent_crimes_by_courts.csv', '40_02_Custodial_death_person_not_remanded.csv', '40_04_Custodial_death_during_hospitalization_or_treatment.csv', '10_Property_stolen_and_recovered.csv', '25_Complaints_against_police.csv', '32_Murder_victim_age_sex.csv', 'crime', '29_Period_of_trials_by_courts.csv', '42_Cases_under_crime_against_women.csv', '31_Serious_fraud.csv', '39_Specific_purpose_of_kidnapping_and_abduction.csv', '36_Police_housing.csv', '33_CH_not_murder_victim_age_sex.csv', '43_Arrests_under_crime_against_women.csv', '40_05_Custodial_death_others.csv', '35_Human_rights_violation_by_police.csv', '40_03_Custodial_death_during_production.csv', '40_01_Custodial_death_person_remanded.csv', '30_Auto_theft.csv']

# %%
import pandas as pd

df = pd.read_csv('/content/crime_data/20_Victims_of_rape.csv')

print(df.head())
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
import pandas as pd
import os

folder = '/content/crime_data'

files = [f for f in os.listdir(folder) if f.endswith('.csv')]

for file in files:
    try:
        df = pd.read_csv(os.path.join(folder, file))
        print("OK:", file)
    except Exception as e:
        print("ERROR:", file)
        print(e)
# Out:
# OK: 20_Victims_of_rape.csv
# OK: 28_Trial_of_violent_crimes_by_courts.csv
# OK: 40_02_Custodial_death_person_not_remanded.csv
# OK: 40_04_Custodial_death_during_hospitalization_or_treatment.csv
# OK: 10_Property_stolen_and_recovered.csv
# OK: 25_Complaints_against_police.csv
# OK: 32_Murder_victim_age_sex.csv
# OK: 29_Period_of_trials_by_courts.csv
# ERROR: 42_Cases_under_crime_against_women.csv
# Error tokenizing data. C error: Expected 22 fields in line 2452, saw 23
#
# OK: 31_Serious_fraud.csv
# OK: 39_Specific_purpose_of_kidnapping_and_abduction.csv
# ERROR: 36_Police_housing.csv
# Error tokenizing data. C error: Expected 7 fields in line 698, saw 9
#
# OK: 33_CH_not_murder_victim_age_sex.csv
# ERROR: 43_Arrests_under_crime_against_women.csv
# Error tokenizing data. C error: Expected 16 fields in line 2452, saw 17
#
# OK: 40_05_Custodial_death_others.csv
# OK: 35_Human_rights_violation_by_police.csv
# OK: 40_03_Custodial_death_during_production.csv
# ...

# %%
import pandas as pd
import os

folder = '/content/crime_data'

files = [f for f in os.listdir(folder) if f.endswith('.csv')]

data = {}

for file in files:
    try:
        data[file] = pd.read_csv(os.path.join(folder, file))
        print(" Loaded:", file)
    except Exception as e:
        print(" Skipped:", file)
        print("Error:", e)

print("\nTotal successfully loaded:", len(data))
# Out:
#  Loaded: 20_Victims_of_rape.csv
#  Loaded: 28_Trial_of_violent_crimes_by_courts.csv
#  Loaded: 40_02_Custodial_death_person_not_remanded.csv
#  Loaded: 40_04_Custodial_death_during_hospitalization_or_treatment.csv
#  Loaded: 10_Property_stolen_and_recovered.csv
#  Loaded: 25_Complaints_against_police.csv
#  Loaded: 32_Murder_victim_age_sex.csv
#  Loaded: 29_Period_of_trials_by_courts.csv
#  Skipped: 42_Cases_under_crime_against_women.csv
# Error: Error tokenizing data. C error: Expected 22 fields in line 2452, saw 23
#
#  Loaded: 31_Serious_fraud.csv
#  Loaded: 39_Specific_purpose_of_kidnapping_and_abduction.csv
#  Skipped: 36_Police_housing.csv
# Error: Error tokenizing data. C error: Expected 7 fields in line 698, saw 9
#
#  Loaded: 33_CH_not_murder_victim_age_sex.csv
#  Skipped: 43_Arrests_under_crime_against_women.csv
# Error: Error tokenizing data. C error: Expected 16 fields in line 2452, saw 17
#
#  Loaded: 40_05_Custodial_death_others.csv
# ...

# %%
df = pd.read_csv(
    '/content/crime_data/30_Auto_theft.csv',
    on_bad_lines='skip'
)

# %%
import pandas as pd

df = pd.read_csv('/content/crime_data/20_Victims_of_rape.csv')

print(df.head())
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
print("Rows, Columns:", df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)

print("\nDataset Info:")
df.info()
# Out:
# Rows, Columns: (1050, 11)
#
# Column Names:
# ['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported', 'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs', 'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs', 'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total', 'Victims_Upto_10_Yrs']
#
# Data Types:
# Area_Name                    object
# Year                          int64
# Subgroup                     object
# Rape_Cases_Reported           int64
# Victims_Above_50_Yrs          int64
# Victims_Between_10-14_Yrs     int64
# Victims_Between_14-18_Yrs     int64
# Victims_Between_18-30_Yrs     int64
# Victims_Between_30-50_Yrs     int64
# Victims_of_Rape_Total         int64
# Victims_Upto_10_Yrs           int64
# dtype: object
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
# ...

# %%
print(df.isnull().sum())
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64

# %%
missing = df.isnull().sum()
percentage = (missing / len(df)) * 100

print(percentage)
# Out:
# Area_Name                    0.0
# Year                         0.0
# Subgroup                     0.0
# Rape_Cases_Reported          0.0
# Victims_Above_50_Yrs         0.0
# Victims_Between_10-14_Yrs    0.0
# Victims_Between_14-18_Yrs    0.0
# Victims_Between_18-30_Yrs    0.0
# Victims_Between_30-50_Yrs    0.0
# Victims_of_Rape_Total        0.0
# Victims_Upto_10_Yrs          0.0
# dtype: float64

# %%
missing = df.isnull().sum()
percentage = (missing / len(df)) * 100

print(percentage)
# Out:
# Area_Name                    0.0
# Year                         0.0
# Subgroup                     0.0
# Rape_Cases_Reported          0.0
# Victims_Above_50_Yrs         0.0
# Victims_Between_10-14_Yrs    0.0
# Victims_Between_14-18_Yrs    0.0
# Victims_Between_18-30_Yrs    0.0
# Victims_Between_30-50_Yrs    0.0
# Victims_of_Rape_Total        0.0
# Victims_Upto_10_Yrs          0.0
# dtype: float64

# %%
print("Duplicates:", df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
df = df.drop_duplicates()

# %%
print("Duplicates after cleaning:", df.duplicated().sum())
# Out:
# Duplicates after cleaning: 0

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_')

# %%
print(df.columns.tolist())
# Out:
# ['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported', 'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs', 'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs', 'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total', 'Victims_Upto_10_Yrs']

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('/content/crime_data/20_Victims_of_rape.csv')

# 1. Remove extra spaces from column names
df.columns = df.columns.str.strip()

# 2. Check missing values
print("Missing values:")
print(df.isnull().sum())

# 3. Check duplicates
print("\nDuplicates:", df.duplicated().sum())

# 4. Remove duplicate rows
df = df.drop_duplicates()

# 5. Clean text columns
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip()

# 6. Check data types
print("\nData types:")
print(df.dtypes)

# 7. Statistical summary
print("\nStatistics:")
print(df.describe())

# 8. Final shape
print("\nFinal shape:", df.shape)
# Out:
# Missing values:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64
#
# Duplicates: 0
#
# Data types:
# Area_Name                    object
# Year                          int64
# Subgroup                     object
# Rape_Cases_Reported           int64
# Victims_Above_50_Yrs          int64
# Victims_Between_10-14_Yrs     int64
# Victims_Between_14-18_Yrs     int64
# Victims_Between_18-30_Yrs     int64
# Victims_Between_30-50_Yrs     int64
# Victims_of_Rape_Total         int64
# Victims_Upto_10_Yrs           int64
# dtype: object
#
# Statistics:
#              Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# ...

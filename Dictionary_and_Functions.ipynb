# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashwat-gla/Python_Assignment/blob/main/Dictionary_and_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dictionary
# it stores in form of key and value
# Name : "kiran"
student = {
    "name":"Neha","age":18,"branch":"CSE-DS","CGPA":8.5
}
print(student)
print(student["name"])
# Out:
# {'name': 'Neha', 'age': 18, 'branch': 'CSE-DS', 'CGPA': 8.5}
# Neha

# %%
#function
#def fuction_name():
  #statements


def greet():
  print("Welcome to Python Programming")
greet()
# Out:
# Welcome to Python Programming

# %%
def greet_student():
  name=input("Enter Your Name:")
  print("Welcome",name)
greet_student()
# Out:
# Enter Your Name:Shashwat
# Welcome Shashwat

# %%
def add(a,b):
  print("sum",a+b)

num1=int(input("Enter First Number:"))
num2=int(input("Enter Second Number:"))

add(num1,num2)
# Out:
# Enter First Number:4
# Enter Second Number:5
# sum 9

# %%
def add(a,b):
  return a+b
num1=int(input("Enter First Number:"))
num2=int(input("Enter Second Number:"))
result=add(num1,num2)
print("sum",result)
# Out:
# Enter First Number:5
# Enter Second Number:6
# sum 11
